# %%
import os
import torch
from datasets import load_from_disk

# %%
DATASETS_FOLDER = os.environ["DATA_HOME"]

# %%
dataset_dict = load_from_disk(DATASETS_FOLDER+"/amazon_review_reproduce/amazon-long-subclass-multi-alpha-300k")

# %%
dataset_dict["train"][0]
# Out:
# {'inputs': 'Write a review for the product given the product title and category. Product Title: Furinno 10002EX/BR 3 Shelves Cabinet/Bedside Night Stand with 2 Bin Drawers, Espresso Finish. Category: Furniture.',
#  'targets': "Junk.  I bought 2.  Took forever to put together the first one together only to find out that, although I generally like the dark wood look, the legs on it were light gray and plastic!  WHY????  It's a decent looking piece of furniture but - GRAY PLASTIC LEGS ON IT?<br /><br />Then I took on the task of building the 2nd one.  In the process, I discovered that there were dowel holes missing, but not until most of the dowels snapped in half rendering the piece useless!<br /><br />When I submitted the item for return I was notified I would not be receiving a refund as more than 7 days had elapsed!  IT TOOK ME 7 DAYS TO PUT THE FIRST ONE TOGETHER.<br /><br />That's $50 I could have put in my gas tank or thrown out the window for that matter.",
#  'alpha': 0.0}

# %%
dataset_dict["test"][0]
# Out:
# {'inputs': 'Write a review for the product given the product title and category. Product Title: Classic Brands Wooden Bed Slats Bunkie Board Frame for Any Mattress Type. Category: Furniture.',
#  'targets': 'Arrived with chunks missing out of the boards - unfortunately, I ordered this, along with several other items as a present for my son for his birthday and waited too long to open, and cannot return as it was past 30 days.  My bad for trying to get everything together ahead of time.  Flimsily made and the boards slide around.',
#  'alpha': 0.0}
